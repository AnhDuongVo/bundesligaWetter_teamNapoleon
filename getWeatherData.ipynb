# %%
from wwo_hist import retrieve_hist_data
import os
import urllib.request

# %% [markdown]
# ## Using Weather API to get weather data
#
# (Source: World Weather Online https://www.worldweatheronline.com/developer/)

# %%
FREQUENCY = 3
START_DATE = '1-JAN-2009'
END_DATE = '5-JUN-2020'
API_KEY = 'fc702ae76aef47c99bd120902200506'
LOCATION_LIST = ['berlin','frankfurt','monchengladbach','wolfsburg','bremen']
    # exemplary cities to receive weather data from

hist_weather_data = retrieve_hist_data(API_KEY,
                                LOCATION_LIST,
                                START_DATE,
                                END_DATE,
                                FREQUENCY,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for berlin
#
#
# Currently retrieving data for berlin: from 2009-01-01 to 2009-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.524394
# Currently retrieving data for berlin: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:02.944528
# Currently retrieving data for berlin: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.525811
# Currently retrieving data for berlin: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.135917
# Currently retrieving data for berlin: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.524481
# Currently retrieving data for berlin: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:09.383897
# Currently retrieving data for berlin: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.696716
# Currently retrieving data for berlin: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.173442
# ...
